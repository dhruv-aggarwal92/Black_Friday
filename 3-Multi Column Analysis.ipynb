# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('Black Friday.csv')
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
del data["Product_Category_2"]
del data["Product_Category_3"]

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Age',hue = 'Gender', data=data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Age',hue = 'Marital_Status', data=data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Gender',hue = 'Age', data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.countplot(x='City_Category',hue = 'Gender', data=data)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.countplot(x='City_Category',hue = 'Age', data=data)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
data.groupby('City_Category').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.countplot(x='City_Category',hue = 'Gender', data=data)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.countplot(x='Marital_Status',hue = 'Gender', data=data)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
data.groupby('City_Category').mean()['Purchase'].plot(kind='pie',autopct='%.1f')
# Out:
# C:\Users\win10\AppData\Local\Temp\ipykernel_1068\3094028122.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('City_Category').mean()['Purchase'].plot(kind='pie',autopct='%.1f')
# <Axes: ylabel='Purchase'>
