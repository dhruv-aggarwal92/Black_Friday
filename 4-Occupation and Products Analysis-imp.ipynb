# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('Black Friday.csv')
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
del data["Product_Category_2"]
del data["Product_Category_3"]

# %%
sns.countplot(x=data['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Gender', data= data)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Marital_Status', data= data)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='City_Category', data= data)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Occupation',data=data)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
data.groupby('Occupation').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
data.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind='bar')
# Out:
# C:\Users\win10\AppData\Local\Temp\ipykernel_9992\1933390421.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind='bar')
# <Axes: xlabel='Occupation'>

# %%
data.groupby('Occupation').mean()['Purchase'].sort_values().plot(kind='bar')
# Out:
# C:\Users\win10\AppData\Local\Temp\ipykernel_9992\378341316.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Occupation').mean()['Purchase'].sort_values().plot(kind='bar')
# <Axes: xlabel='Occupation'>

# %%
# sns.set(rc={'figure.figsize':(12,6)})

sns.countplot(x='Occupation',hue = 'Gender',data=data)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x='Occupation',hue = 'Marital_Status',data=data)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
data.groupby('Occupation').nunique()
# Out:
#             User_ID  Product_ID  Gender  Age  City_Category  \
# Occupation
# 0               688        3243       2    7              3
# 1               517        3020       2    7              3
# 2               256        2892       2    7              3
# 3               170        2657       2    6              3
# 4               740        3174       2    6              3
# 5               111        2344       2    6              3
# 6               228        2724       2    6              3
# 7               669        3070       2    7              3
# 8                17        1026       2    7              3
# 9                88        1820       2    6              3
# 10              192        2110       2    5              3
# 11              128        2235       2    7              3
# 12              376        2664       2    7              3
# 13              140        1946       2    5              3
# 14              294        2680       2    7              3
# 15              140        2168       2    6              3
# 16              235        2863       2    6              3
# 17              491        2831       2    7              3
# 18               67        2047       2    6              3
# 19               71        2303       2    7              3
# 20              273        3147       2    6              3
#
#             Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# Occupation
# 0                                    5               2                  18
# 1                                    5               2                  18
# 2                                    5               2                  18
# 3                                    5               2                  18
# 4                                    5               2                  18
# 5                                    5               2                  18
# 6                                    5               2                  18
# 7                                    5               2                  18
# 8                                    4               2                  17
# 9                                    5               2                  18
# 10                                   5               2                  18
# 11                                   5               2                  18
# 12                                   5               2                  18
# 13                                   5               2                  18
# 14                                   5               2                  18
# 15                                   5               2                  18
# 16                                   5               2                  18
# 17                                   5               2                  18
# 18                                   5               2                  18
# 19                                   5               2                  18
# 20                                   5               2                  18
#
#             Purchase
# Occupation
# 0              12785
# 1              11305
# 2               9314
# 3               7790
# 4              12764
# 5               6520
# 6               8273
# 7              12042
# 8               1395
# 9               4089
# 10              6967
# 11              6313
# 12             10022
# 13              4694
# 14              9335
# 15              6433
# 16              9190
# 17             10821
# 18              4511
# 19              5338
# 20             10471

# %%
data.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
data.groupby('Product_Category_1').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
data.groupby('Product_Category_1').mean()['Purchase'].sort_values().plot(kind='bar')
# Out:
# C:\Users\win10\AppData\Local\Temp\ipykernel_9992\3744807415.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Product_Category_1').mean()['Purchase'].sort_values().plot(kind='bar')
# <Axes: xlabel='Product_Category_1'>

# %%
data.groupby('Product_ID').mean()['Purchase'].nlargest(10).sort_values().plot(kind='bar')
# Out:
# C:\Users\win10\AppData\Local\Temp\ipykernel_9992\1728958033.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Product_ID').mean()['Purchase'].nlargest(10).sort_values().plot(kind='bar')
# <Axes: xlabel='Product_ID'>

# %%
data.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>
